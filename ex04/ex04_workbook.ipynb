# %% [markdown]
# # Exercise 04 — Workbook: dock your own protein
#
# This notebook is **deliberately almost empty**, and it is entirely about **your** protein
# — the one you picked in ex01's Character Sheet, predicted in ex02, and simulated in ex03.
#
# Its companion, **`ex04_guide.ipynb`**, works the whole pipeline through on HIV-1 protease
# + darunavir (PDB 2IEN), and separately walks a real cheminformatics debugging exercise.
# **Read the guide first.** Then work here, with it open beside you.
#
# ## How to work in this notebook
#
# - **Copy code across from the guide and adapt it.** Fetch, split receptor/ligand, prepare
#   PDBQT, define the box, dock, score, RMSD, PLIP — all of it is generic.
# - **Structure the notebook however you like.** The sections below are a checklist, not a
#   cell-by-cell template.
# - **The reasoning is what's graded, not the code.** A docking score with no interpretation
#   is worth very little; a modest score you can explain is worth a lot.
#
# ## Using AI Tools
#
# You may use AI assistants for RDKit/Vina syntax, debugging, and code snippets. You must
# supply the chemical reasoning, the justification for your choices, and the critical
# evaluation of what came back. **"The AI said so" is not an answer.**
#
# **Note:** the prompts below are predict-first — you write your prediction down *before*
# you run anything. That written prediction is the graded artefact.

# %% [markdown]
# ---
#
# ## 1. Your protein and its ligand — already established
#
# You do **not** need to pick a ligand. It was **named in your assignment** and recorded on
# your ex01 Character Sheet: a real, biologically meaningful ligand in the crystal, checked
# in advance so you are not docking a buffer molecule. You characterised its binding site in
# ex03 §5a, and — if you got §5b working — you have already simulated the complex.
#
# So this exercise is not "find something to dock". It is:
#
# > **Take a ligand whose real bound pose you already know, dock it back, and find out
# > whether docking recovers what the experiment and the simulation already told you.**
#
# Record what you are bringing forward:
#
# | From | What you have |
# |---|---|
# | **ex01** | the PDB entry, its resolution, and the conserved positions |
# | **ex03 §5a** | the residues within 4 Å of the ligand, and the contact types |
# | **ex03 §5b/5c** | the complex trajectory, if it ran — the ligand's own RMSD, and whether the site rigidified |
#
# > **My protein / ligand (CCD code):**
# >
# > **My ex03 contact residues:**
#
# **If your assigned entry turns out not to contain the named ligand** — you should have
# caught this back in ex01, but check again now — stop and raise it rather than substituting
# a molecule of your own. The whole comparison in section 5 depends on having a real
# experimental pose to measure against.

# %% [markdown]
# ## 2. Predict first, before you dock
#
# **Before running anything,** write down:
#
# - Which **pocket** do you expect the ligand to occupy? Name the residues.
# - Which **interaction types** do you expect to matter most — H-bonds, hydrophobic
#   contacts, salt bridges, pi-stacking? Why, from the chemistry of your ligand?
# - If you have a crystal pose: what **self-dock RMSD** would you call a success? Justify
#   the threshold rather than quoting one.
#
# Use what you already know about this protein: the conserved residues from **ex01**, the
# confident/unconfident regions from **ex02**, and the flexible/rigid regions from **ex03**.
# A pocket you measured as mobile in ex03 is a pocket rigid docking will struggle with.
#
# > **My prediction:**
# >
# > **My reasoning, citing my ex01 / ex02 / ex03 findings:**

# %% [markdown]
# ## 3. Prepare, dock, and validate
#
# Adapt the guide's pipeline: fetch → split receptor and ligand → prepare PDBQT (hydrogens
# at pH 7.4, charges) → define the search box → dock.
#
# **If you have a native crystal pose, self-dock first.** Compute the RMSD between your
# top pose and the real one, matching heavy atoms as the guide does.
#
# **This validation step is not optional bookkeeping — it is what makes the rest
# meaningful.** If the method cannot reproduce a pose you already know is correct, its score
# on anything unknown is not evidence. Report the RMSD and say plainly whether the pipeline
# passed.
#
# **If you have no crystal pose,** say so explicitly, and explain what you can and cannot
# conclude without that check.

# %% [markdown]
# ## 4. Analyse the interactions
#
# Run PLIP on your top-scoring complex and describe the binding mode **in your own words**:
#
# - Which residues form **hydrogen bonds**? Which form **hydrophobic contacts**? Any
#   **salt bridges** or **pi-stacking**?
# - Is the contact profile consistent with your ligand's chemistry — does a large nonpolar
#   molecule show mostly hydrophobic contacts, does a charged one show salt bridges?
# - **How did your section 2 prediction hold up?** Name what you got right and wrong.
# - Do any contacting residues coincide with the **conserved positions you found in ex01**?
#   If yes, that is real evidence the pocket is functionally important. If no, say so — an
#   honest negative is worth more than a forced connection.

# %% [markdown]
# ## 5. The comparison this exercise exists for
#
# You now have up to **three** descriptions of the same ligand in the same pocket:
#
# | Source | What it is | From |
# |---|---|---|
# | **Crystal pose** | one experimental snapshot, the ground truth | ex01 / the PDB |
# | **MD-sampled poses** | how the ligand actually moved with water and thermal motion | ex03 §5b, if it ran |
# | **Docking poses** | what a search algorithm predicts against a rigid receptor | section 3 above |
#
# **Compare them properly, not just the top pose against the crystal:**
#
# - **Docked vs. crystal** — you have the self-dock RMSD. Which parts of the ligand are
#   placed well, and which are not? A good overall RMSD can hide a badly-placed substituent.
# - **Docked vs. MD** — did the ligand, in simulation, visit conformations resembling any of
#   your *lower-ranked* docking poses? If it did, that is direct evidence those poses were
#   not noise, and that Vina's ranking is not the same thing as physical plausibility.
# - **The contact residues** — compare the three lists: contacts in the crystal (ex03 §5a),
#   contacts sampled during MD (§5c), and contacts in the docked pose (section 4). Which
#   contacts are present in all three? Those are the robust ones.
#
# **Then answer the question the three views exist to settle:**
#
# > Docking treats the receptor as rigid. You measured, in ex03, how rigid your pocket
# > actually is. **Given your own RMSF numbers, how much should you trust this docking
# > result?**
#
# This is the ex03 Frontier prediction coming due. Go back to what you wrote there — you
# predicted whether flexibility would make docking easier or harder. **Were you right?**
# Quote your prediction and judge it against what you have now measured.
#
# > **My ex03 prediction was:**
# >
# > **What the comparison actually shows:**
#
# **If ex03 §5b did not run for you,** do the two-way comparison (crystal vs. docked) and
# state plainly which conclusions you cannot reach without the MD. Naming the limit is the
# graded part; having the data is not.

# %% [markdown]
# ## 6. Critical evaluation
#
# Docking scores are **not** binding free energies, and they are not comparable between
# different proteins. With that in mind:
#
# - What does your score actually justify claiming? What does it not?
# - The guide's 2JAC Frontier asked whether pocket flexibility makes docking harder. You
#   measured your own protein's flexibility in **ex03** — so answer it for real this time:
#   how much should you trust a rigid-receptor docking result for *your* pocket?
# - Name **one modification** — to the ligand or the protein — that you predict would
#   improve or worsen binding, and justify it from an interaction you can actually see in
#   your PLIP output.

# %% [markdown]
# ---
#
# ## Before you submit
#
# - [ ] Protein/ligand and the ex03 contact residues carried forward (section 1)
# - [ ] Section 2 prediction **written before** docking
# - [ ] Self-dock RMSD reported **or** its absence explicitly explained
# - [ ] PLIP interactions described in your own words, not pasted raw
# - [ ] Prediction explicitly checked against the result, including what you got wrong
# - [ ] Section 5 three-way comparison done — or the two-way version, with the limit stated
# - [ ] Your **ex03 Frontier prediction** quoted and judged against the result
# - [ ] Cross-links back to your ex01 conservation, ex02 confidence, and ex03 flexibility
# - [ ] Anything that didn't work is **described honestly** rather than deleted — a
#       documented dead end earns marks, a silently missing section does not
