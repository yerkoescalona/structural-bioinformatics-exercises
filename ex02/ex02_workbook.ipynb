# %% [markdown]
# # Exercise 02 — Workbook: your own protein
#
# This notebook is **deliberately almost empty**, and it is entirely about **your** protein
# — the one you picked in ex01's Character Sheet, which you carry through ex03, ex04 and
# your final project.
#
# Its companion, **`ex02_guide.ipynb`**, works everything through on human p53 / PDB 3D08
# with every cell filled in, and separately demonstrates sequence design. **Read the guide
# first.** Then work here, with it open beside you.
#
# ## How to work in this notebook
#
# - **Copy code across from the guide and adapt it.** The AlphaFold DB API calls, the
#   pLDDT plot, the PAE heatmap and the Kabsch-superposition cell are all generic — they
#   work on any protein with an AlphaFold DB entry. Reusing them is the point.
# - **Structure the notebook however you like.** The sections below are a checklist of what
#   has to be here, not a cell-by-cell template.
# - **The reasoning is what's graded, not the code.** Every section asks for a written
#   conclusion as well as output.
# - **No GPU needed.** Everything asked for here is HTTP calls and plotting.
#
# ## Setup
#
# You need the same libraries as the guide — copy its setup cell across.
#
# ## Using AI Tools
#
# You may use AI assistants for syntax, debugging, and code snippets. You must supply the
# design strategy (**why** you chose specific amino acids), the hypotheses, the critical
# evaluation, and the biological reasoning. **"The AI said so" is not an answer.**
#
# **Note:** several prompts below are predict-first — you write your prediction down
# *before* you run anything. That written prediction is the graded artefact. Being wrong
# costs you nothing; not having made a prediction costs you the marks.

# %% [markdown]
# ---
#
# # Part A — Your protein's AlphaFold prediction
#
# ## A.1 Predict first, before you fetch anything
#
# **Check [the AlphaFold Database](https://alphafold.ebi.ac.uk/) for your protein.** If it
# isn't there, use the [AlphaFold Server](https://alphafoldserver.com/welcome) or
# [ColabFold](https://colab.research.google.com/github/sokrypton/ColabFold/blob/main/AlphaFold2.ipynb).
#
# **Before you look at a single number,** write your prediction: will AlphaFold's confidence
# be roughly uniform across your protein, or split into confident and unconfident stretches?
# If split, which parts do you expect to be confident, and why?
#
# **Use the evidence you already have.** In ex01 you found, for this same protein, which
# residues its crystal failed to resolve and which resolved residues had the highest
# B-factors. Go back to that notebook and use those two findings as the basis for this
# prediction — name the specific regions, and say what about them makes you expect low
# confidence. "I don't know" is not a prediction; a wrong prediction with stated reasoning
# is worth full marks.
#
# > **My prediction:**
# >
# > **My reasoning (citing my ex01 B-factor and unresolved-residue findings):**

# %% [markdown]
# ## A.2 Confidence analysis
#
# Produce, for your own protein:
#
# - Global mean pLDDT and the confidence-bin fractions
# - A per-residue **pLDDT plot**
# - A **PAE heatmap**
#
# **Then answer:**
# - Which regions have the highest confidence (pLDDT > 90), and why? (Secondary structure?
#   Core vs. surface?)
# - Which regions have the lowest (pLDDT < 70), and why? (Loops? Disordered? Termini?)
# - What does the PAE matrix tell you about your protein's architecture — which domains are
#   well-resolved, which inter-domain contacts are uncertain?
# - How did your A.1 prediction hold up? If it was wrong, what did you miss?

# %% [markdown]
# ## A.3 Comparison against an experimental structure
#
# If your protein has **both** an AlphaFold DB entry and a solved experimental structure,
# superimpose them using the guide's Kabsch cell and report:
#
# - Overall CA RMSD, and over how many matched residues
# - The highest-deviation regions
# - **Why** those regions differ — is it near an unresolved crystal loop? A mutation? A
#   bound ligand or ion the model cannot contain? Or a genuinely wrong prediction?
#
# If your protein has only one or the other, **say so explicitly** rather than forcing the
# comparison. That is a real, informative outcome, not a failure.

# %% [markdown]
# ---
#
# # Part B — The metrics beyond pLDDT
#
# pLDDT answers one question: *can the model place this atom?* Your protein's prediction
# carries more than that, and the rest is where the interesting reading is.
#
# ## B.1 Confidence composition
#
# Report the four `fractionPlddt*` bands for your protein alongside the headline mean.
#
# **Then interpret the shape, not the average.** Is your protein uniformly mediocre, or —
# like p53 — excellent in one region and honestly uncertain elsewhere? Those are completely
# different situations that can produce the same mean. Which is yours?

# %% [markdown]
# ## B.2 AlphaMissense: which positions cannot change
#
# Fetch your protein's AlphaMissense annotations (`amAnnotationsUrl` in the prediction
# record) and produce:
#
# - a **per-position mean pathogenicity track**, plotted directly under your pLDDT track on
#   a shared x-axis
# - a **heatmap** of substitutions for a region you care about
#
# **Then answer, with numbers:**
#
# - Do the two tracks have the same shape? Where do they **disagree** — positions confidently
#   placed but freely mutable, or poorly placed but intolerant? Those disagreements are the
#   interesting residues.
# - What is the mean pathogenicity inside your ligand-binding site versus the rest of the
#   protein?
#
# **If AlphaMissense is unavailable for your protein**, say so and explain why — it covers
# human proteins, so a bacterial or viral target will not have it. That is a real finding
# about the limits of these resources, not a failure.

# %% [markdown]
# ## B.3 The convergence test
#
# This is the part worth doing carefully. You now have **three independent lines of
# evidence** about which residues matter, produced by completely different methods:
#
# | Evidence | From | Method |
# |---|---|---|
# | Conserved positions | **ex01** | multiple sequence alignment |
# | Ligand-contact residues | **ex01** | a distance calculation on the crystal |
# | Intolerant positions | **B.2** | a variant-effect model trained on population genetics |
#
# **Compute the overlap between all three**, and compare it against what you would expect by
# chance — the same baseline discipline you used in ex01. Report the observed overlap, the
# chance expectation, and the ratio.
#
# Agreement between independent methods is worth far more than a strong result from any one
# of them. Where all three agree, you have a genuinely well-supported claim about which
# residues do the work. Where they disagree, say so — a disagreement you can characterise is
# a better answer than a convergence you had to force.
#
# > **Overlap of all three:**
# >
# > **Expected by chance:**
# >
# > **What I conclude, and what I cannot:**

# %% [markdown]
# ---
#
# ## Before you submit
#
# - [ ] A.1 prediction **written before** the analysis in A.2, citing your ex01 findings
# - [ ] pLDDT plot and PAE heatmap produced for your own protein
# - [ ] A.3 comparison done, **or** explicitly explained why it could not be
# - [ ] B.1 confidence **composition** reported and interpreted — not just the mean
# - [ ] B.2 AlphaMissense track plotted against pLDDT, **or** its absence explained
# - [ ] B.3 three-way overlap reported **with its chance baseline**, not as a bare count
# - [ ] Anything that didn't work is **described honestly** rather than deleted — a
#       documented dead end earns marks, a silently missing section does not
